# %% [markdown]
# # **GenoVarDis@IberLEF2024: Automatic Genomic Variants and Related Diseases using Named Entity Recognition with Large Language Models**
#
# ## Autor: Víctor Manuel Oliveros Villena

# %%
# Esta es la ruta a la raíz de nuestro Drive.
# Si se prefiere otra ruta, añadir los directorios pertinentes a continuación de esta.
path_drive = '/content/drive/MyDrive'

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Instalacion de bibliotecas necesarias
# !pip install -q openai==0.28
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.4 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
from google.colab import drive
import openai
import re

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Lectura de archivos**

# %%
# Ruta al archivo TSV en Google Drive
path_test_text = path_drive + '/GenoVarDis/Data/test_text.tsv'

# Lectura del archivo TSV utilizando pandas
data = pd.read_csv(path_test_text, sep='\t')

# %% [markdown]
# ### **Configuración del modelo GPT**

# %%
# Por motivos de privacidad, las URL de punto de acceso y la API Key no han
# podido ser compartidas
openai.api_type = 'azure'         # Tipo de API Azure
openai.api_base = 'URL'           # URL del punto de acceso
openai.api_version = '2023-05-15' # Versión de la API a emplear
openai.api_key = 'KEY'            # Clave de la API para autenticación

# %%
# Prompt a emplear en el modelo GPT para servirle como contexto de la tarea a
# realizar
system_content = '''Eres un modelo de inteligencia artificial especializado en el reconocimiento de entidades nombradas (NER) en el campo de la biomedicina.
Debes identificar sola y únicamente los siguientes tipos de entidades en el texto: "Gene", "Disease", "DNAMutation", "SNP", "DNAAllele", "NucleotideChange-BaseChange", "OtherMutation", "Transcript". Cualquier otra etiqueta daría lugar a error.
Recuerda que no todas estas entidades necesariamente aparecerán en cada caso clínico, pero debes ser riguroso al clasificarlas según corresponda.
Los resultados, siempre y cuando se hayan detectado entidades, deben mostrarse exactamente en el formato: {tipo entidad} --> {entidad}\n. Escribe cada entidad encontrada en una línea distinta, aunque sean del mismo tipo.
Además, es muy importante que aparezcan por orden de aparición y escritas exactamente igual que en el texto (tildes, mayúsculas). En caso de no encontrar entidades devuelve un string vacío: '' '''

# %% [markdown]
# ### **Ejecución del modelo y generación del archivo TSV con los resultados**

# %%
# Ruta donde guardaremos el archivo con las anotaciones realizadas
filename = path_drive + '/GenoVarDis/EvaluationTSV/annotationGPT3.5Turbo.tsv'
# Nombre de las columnas de dicho archivo TSV
tags = 'pmid\tfilename\tlabel\toffset1\toffset2\tspan\n'
# Tipos de entidades
labels = ["Gene", "Disease", "DNAMutation", "SNP", "DNAAllele", "NucleotideChange-BaseChange", "OtherMutation", "Transcript"]

# %%
def detect_entities(text):
    """
    Detecta entidades en el texto proporcionado utilizando el modelo GPT-3.5 Turbo de OpenAI.

    Args:
        text (str): Caso clinico donde identificar las entidades.

    Returns:
        str: Un string que contiene las entidades detectadas en el formato '{tipo entidad} --> {entidad}\n'.
    """
    response = openai.ChatCompletion.create(
        engine='gpt-35-turbo-model',
        messages=[
            {'role': 'system', 'content': system_content}, # Nuestro prompt
            {'role': 'user', 'content': text}              # Caso clinico
        ]
    )
    return response['choices'][0]['message']['content']

with open(filename, 'w') as file:
  file.write(tags)  # Escribe las etiquetas de las columnas en el TSV
  # Para cada caso clinico...
  for i, clinic_case in data.iterrows():
    pmid = clinic_case['pmid']  # Obtenemos pmid
    ann = clinic_case['filename'].replace('.txt', '.ann') # Generamos nombre del archivo
    text = clinic_case['text']  # Obtenemos el texto del caso clinico
    # Establece los offsets iniciales
    offset1 = 0
    offset2 = 0
    set_of1 = set()
    set_of2 = set()

    # Detecta las entidades mediante GPT
    entities = detect_entities(text)
    # Guarda una lista con cada una de las entidades
    list_entitites = entities.split('\n')

    # Mostramos los resultados
    print(list_entitites)

    # Por cada entidad detectada en un caso clinico...
    for entity in list_entitites:
      # Dividimos la entidad de su tipo
      entity_split = entity.split('-->')
      # Si el formato devuelto por GPT es incorrecto, ignoramos dicha entidad
      if entity == '' or len(list_entitites) == 1 or len(entity_split) != 2:
        continue
      # Ajustamos el formato de las entidades y sus tipos
      label, span = entity_split
      span = span.strip()
      label = label.strip()
      # Si el tipo de entidad no corresponde con los indicados, ignoramos la entidad
      if label not in labels:
        continue
      # Patron de busqueda de la entidad
      pattern = rf'\b{re.escape(span)}\b'
      # Iterador con todas las coincidencias de esta en el caso clinico
      matches = re.finditer(pattern, text)

      # Guarda la posicion de inicio y fin de la entidad en el caso clinico
      for m in matches:
        if m.start() not in set_of1 and m.end() not in set_of2:
          offset1 = m.start()
          offset2 = m.end()
          set_of1.add(offset1)
          set_of2.add(offset2)
          break
      # Añade la entidad al archivo TSV
      file.write(f"{pmid}\t{ann}\t{label}\t{offset1}\t{offset2}\t{span}\n")
# Out:
# ['Gene --> PTCH1', 'DNAMutation --> c.930delC', 'Disease --> Síndrome de Gorlin', 'OtherMutation --> heterocigosis']
# ['Disease --> sindrome cri du chat (SCDC)', 'DNAMutation --> delecion', 'OtherMutation --> traslocacion', 'OtherMutation --> inversion', 'Gene --> TERT', 'NucleotideChange-BaseChange --> 5p15.33 (151537-3057771)x1']
# ['Gene --> PMP22', 'Disease --> Charcot-Marie-Tooth', 'Disease --> CMT', 'Disease --> CMT1A', 'DNAMutation --> duplicacion', 'NucleotideChange-BaseChange --> 1,5 Mb', 'OtherMutation --> mutacion', 'Transcript --> tecnica de reaccion en cadena de la polimerasa', 'Transcript --> tecnica de hibridacion in situ fluorescente']
# ['Factores neurotróficos --> neurotroficos', 'Trastorno por déficit de atención/hiperactividad --> TDAH', 'Neurotrofinas --> neurotrofinas', 'Proteínas --> proteinas', 'Sistema nervioso central --> sistema nervioso central', 'Sistema nervioso periférico --> sistema nervioso periferico', 'Conexiones sinápticas --> conexiones sinapticas', 'Factor neurotrófico derivado de cerebro --> BDNF', 'Atomoxetina --> atomoxetina', 'Plasmáticos --> plasmaticos', 'Expresión --> expresion', 'Etiología --> etiologia']
# ['Disease --> enfermedad de Pompe', 'Gene --> GAA', 'DNAAllele --> Gen GAA', 'OtherMutation --> mutaciones descritas en la enfermedad de Pompe', 'DNAMutation --> No hay mutaciones específicamente mencionadas', 'Transcript --> No hay menciones a transcript', 'NucleotideChange-BaseChange --> No hay menciones a cambios de nucleótidos o bases', 'SNP --> No hay menciones a SNP.']
# ['SNP --> SNP-19', 'Gene --> CAPN10', 'Disease --> diabetes mellitus tipo 2 ', 'DNAMutation --> polimorfismo de inserción/deleción', 'DNAAllele --> 2R, 3R', 'NucleotideChange-BaseChange --> no aplica en este caso', 'SNP --> genotipo homocigoto 3R', 'SNP --> genotipo 2R/3R', 'OtherMutation --> no aplica en este caso', 'Transcript --> no aplica en este caso']
# ['Gene --> NRXN1', 'DNAMutation --> microdeleciones', 'OtherMutation --> microdeleciones', 'Gene --> NRXN1', 'DNAMutation --> microdeleciones', 'DNAMutation --> exones alfa', 'Disease --> retraso mental leve-moderado', 'Disease --> trastornos de comportamiento', 'OtherMutation --> rasgos dismorficos o malformaciones', 'Gene --> NRXN1', 'DNAMutation --> microdeleciones', 'DNAMutation --> exones alfa', 'Disease --> macrocefalia', 'Disease --> epilepsia', 'Disease --> retraso mental']
# ['Gene --> PTPN', 'Disease --> Malformacion de Arnold-Chiari', 'Disease --> sindrome de Noonan', 'Gene --> PTPN11', 'Disease --> LEOPARD', 'OtherMutation --> c.922A>G (N308D)', 'OtherMutation --> c.923A>G (N308S)']
# ['Gene --> SOX5', 'Disease --> síndrome con alteracion del neurodesarrollo', 'DNAMutation --> delecion 12p12', 'Gene --> SOX5']
# ['ITA-IC --> Infecciones del tracto urinario de inicio en la comunidad', 'Escherichia coli --> E. coli', 'BLEE --> betalactamasas de espectro extendido', 'Colombia --> Colombia', 'CTX-M-15 --> CTX-M-15 ', 'ST131 --> ST131']
# ['Gene --> TREX1', 'Gene --> RNASEH2B', 'DNAMutation --> mutacion', 'Gene --> ADAR', 'Gene --> IFIH1', 'Gene --> SAMHD1', 'Gene --> MAD5', 'Disease --> sindrome de Aicardi-Goutieres', 'Gene --> RNASEH2B', 'OtherMutation --> mutacion', 'Disease --> encefalopatia subaguda ', 'OtherMutation --> distonia/espasticidad ', 'OtherMutation --> afectacion/regresion del desarrollo psicomotor', 'SNP --> neopterina', 'OtherMutation --> calcificaciones ', 'OtherMutation --> secuenciacion ', 'Transcript --> liquido cefalorraquideo']
# ['Gene --> L1CAM', 'Disease --> Paraplejía espástica hereditaria, SPG1, sindrome CRASH', 'DNAMutation --> mutacion c.516G>A en el exon 5 del gen L1CAM']
# ['DNAMutation --> BRAF V600E', 'Disease --> crisis epilepticas', 'OtherMutation --> mutacion positiva a BRAF']
# ['Disease --> Síndrome de Langer-Giedion', 'Gene --> TRPS1', 'Gene --> RAD21', 'Gene --> EXT1', 'DNAMutation --> deleción heterocigota', 'NucleotideChange-BaseChange --> 8q23.3-q24.11', 'OtherMutation --> deleción en la región cromosómica 8q23.1-q24.12', '']
# ['Gene --> IFIH1', 'Disease --> Sindrome de Aicardi-Goutieres', 'Gene --> IFIH1', 'OtherMutation --> mutacion de novo', 'Disease --> Sindrome de Aicardi-Goutieres', 'Transcript --> interferon induced with helicase C domain 1']
# ['Gene --> RIT1', 'Disease --> sindrome de Noonan', 'DNAMutation --> c.295T>C (p.Phe99Leu)', 'OtherMutation --> de novo en heterocigosis', 'DNAMutation --> alelos mutantes', 'Transcript --> proteinas RAS']
# ['Gene --> TP53', 'Disease --> Glioblastoma multiforme congenito', 'Gene --> TP53', 'Disease --> Glioblastoma multiforme', 'Gene --> TP53']
# ['Disease --> síndrome hiper-IgE', 'OtherMutation --> STAT-3', 'Disease --> síndrome hiper-IgE', 'OtherMutation --> DOCK-8', 'Disease --> síndrome hiper-IgE', 'Gene --> STAT-3', 'Gene --> DOCK-8']
# ['DNAMutation --> HFE H63', 'OtherMutation --> síndrome de Gilbert UGT1A1*28', 'Gene --> HFE', 'Disease --> beta-talasemia ', 'DNAMutation --> HFE H63D', 'DNAMutation --> UGT1A1*28', 'DNAMutation --> HbD Punjab', 'DNAMutation --> HbS']
# ['Gene --> TEL', 'Gene --> AML1', 'Gene --> MLL', 'Gene --> AF4', 'Gene --> BCR', 'Gene --> ABL', 'Gene --> E2A', 'Gene --> PBX1', 'Disease --> leucemia linfoblástica aguda', 'Disease --> leucemias', 'Disease --> cáncer', 'OtherMutation --> translocaciones cromosómicas']
# ['Gene --> EDA', 'Gene --> EDAR', 'Gene --> EDARADD', 'Disease --> Displasia ectodérmica hipohidrótica', 'Disease --> DEH ligada al X', 'Disease --> DEH con patrón de herencia autosómica dominante', 'DNAMutation --> c.1072C>T(p.Arg358X) en el gen EDAR']
# ['Disease --> ictus criptogénico', 'DNAMutation --> mutación en el gen GLA', 'Gene --> GLA', 'Disease --> enfermedad de Fabry', 'OtherMutation --> disminución de la actividad de alfa-galactosidasa-A', 'Transcript --> agalsidasa beta', 'Disease --> insuficiencia renal.']
# ['Gene --> SLC19A2', 'Disease --> síndrome de anemia megaloblástica sensible a la tiamina', 'Disease --> anemia megaloblástica', 'Disease --> hipoacusia neurosensorial', 'Disease --> diabetes mellitus', 'DNAMutation --> mutaciones homocigotas o heterocigotas compuestas', 'DNAMutation --> mutación en el gen SLC19A2', 'DNAMutation --> heterocigotas compuestas', 'Disease --> TRMA', 'OtherMutation --> enfermedad hematológica', 'OtherMutation --> terapia con tiamina', 'OtherMutation --> aumentar dosis terapéutica de tiamina', 'OtherMutation --> asesoramiento genético']
# ['Gene --> DUOX2', 'Disease --> Hipotiroidismo congénito', 'Gene --> DUOX1', 'Gene --> DUOX2', 'Gene --> DUOX2', 'Gene --> DUOX2', 'DNAMutation --> c.1057_1058delTT', 'OtherMutation --> p.F353PfsX36', 'OtherMutation --> p.F353fsX388', 'DNAMutation --> c.1271T>G', 'DNAAllele --> alelo paterno', 'DNAAllele --> alelo materno']
# ['Gene --> SMN1', 'Gene --> SMN2', 'Disease --> atrofia muscular espinal', 'Disease --> AME', 'Drug --> olesoxime', 'Drug --> riluzol', 'OtherMutation --> inhibidores de histona deacetilasa', 'DNAMutation --> oligonucleotidos antisentido', 'DNAMutation --> metoxietilo fosforotioato-oligonucleotido antisentido', 'Drug --> nusinersen', 'Transcript --> terapia genica introduciendo el gen SMN1 mediante virus adenoasociados']
# ['DNAMutation --> metilación', 'Gene --> genes', 'Disease --> síndromes mielodisplásicos', 'OtherMutation --> mutaciones', 'DNAMutation --> transducción', 'Gene --> genes', 'DNAMutation --> regulación', 'DNAMutation --> corte y empalme', 'Disease --> leucemia aguda mieloblástica']
# ['DNAMutation --> polimorfismos', 'Gene --> gen del transportador de serotonina, genes de las enzimas del metabolismo dopaminérgico y del factor neurotrófico derivado del cerebro', 'OtherMutation --> alteraciones hipermetabólicas (desregulación dopaminérgica y glutamatérgica) y luego hipometabólicas-disociativas (desregulación serotoninérgica y opioide)', 'Disease --> alexitimia', 'Transcript --> conexión cerebral interhemisférica reducida', 'OtherMutation --> alteraciones en la corteza prefrontal derecha y la red neuronal por defecto', 'Gene --> rol de la oxitocina es controvertido', 'OtherMutation --> distorsión en la consciencia interoceptiva y emocional', 'DNAMutation --> genes de las enzimas del metabolismo dopaminérgico y del factor neurotrófico derivado del cerebro']
# ['Gene --> GLDC', 'DNAMutation --> c.2516A>G', 'OtherMutation --> p.Y839C', 'DNAMutation --> c.2457+2T>A', 'Disease --> hiperglicinemia no cetósica', 'NucleotideChange-BaseChange --> A>G', 'NucleotideChange-BaseChange --> +2T>A']
# ['Gene --> RET', 'DNAMutation --> 634', 'DNAMutation --> 611', 'DNAMutation --> 918', 'Disease --> microcarcinoma', 'Disease --> carcinoma in situ', 'Disease --> carcinoma medular de tiroides', 'Disease --> hiperplasia', 'Disease --> fibrosis', 'OtherMutation --> MEN2A', 'OtherMutation --> MEN2B', 'Transcript --> calcitonina ', 'Transcript --> calcio', 'Transcript --> paratohormona', 'Transcript --> catecolaminas', 'Transcript --> metanefrinas', '']
# ['Gene --> TSC2', 'Disease --> esclerosis tuberosa', 'Gene --> TSC1', 'Gene --> TSC2', 'DNAAllele --> c.583_586dupATCG', 'DNAMutation --> mutación sin sentido', 'NucleotideChange-BaseChange --> dupATCG', 'OtherMutation --> variante nueva', 'Transcript --> exón 6']
# ['Disease --> mielofibrosis primaria', 'OtherMutation --> mutación JAK2V617F', 'Disease --> TVE (trombosis venosa esplácnica)']
# ['Gene --> RUNX2', 'DNAMutation --> c.674G>A', 'NucleotideChange-BaseChange --> p.R225Q']
# ['SNP --> C677T', 'Gene --> 5,10-metilentetrahidrofolato reductasa (MTHFR)', 'Disease --> cáncer de mama (CM)', 'Gene --> MTHFR', 'NucleotideChange-BaseChange --> C667T ', '']
# ['Protein --> proteínas de fase aguda', 'Test --> LightCycler® SeptiFast', 'OtherClinical -- > reactantes de fase aguda', 'Disease --> infecciones bacterianas', 'Disease --> infecciones virales', 'OtherClinical -- > niños febriles', 'LabValue --> recuento de leucocitos', 'LabValue --> proteína C-reactiva', 'LabValue --> procalcitonina', 'LabValue --> temperatura', 'LabValue --> áreas bajo la curva']
# ['Gene --> CTSA', 'Disease --> galactosialidosis ', 'DNAMutation --> p.His475Pro (c.1424 A>C)', 'DNAMutation --> p.Arg441Cys (c.1321C>T)', 'Transcript --> exones 15', 'Transcript --> exones 14']
# ['Gene --> PAX-2', 'DNAMutation --> p.R104X', 'Disease --> síndrome renal-coloboma', 'OtherMutation --> de novo', 'Disease --> hipoplasia renal bilateral', 'Disease --> enfermedad renal crónica', 'OtherMutation --> heterocigosis']
# ['DNAMutation --> m.8344A>G del gen MTTK del ADN mitocondrial', 'Disease --> miopatia mitocondrial', 'Gene --> MTTK', 'Disease --> debilidad de cinturas', 'DNAMutation --> 8344A>G del ADN mitocondrial']
# ['Gene --> SDHD', 'DNAMutation --> p81L del gen SDHD (11q23)', 'Disease --> tumores del cuerpo carotídeo (TCC) esporádicos', 'Disease --> TCC familiares', 'Disease --> TCC', 'OtherMutation --> heterocigota']
# ['DNAMutation --> TCIRG1', 'DNAMutation --> p.Ile720Alafs*14', 'DNAMutation --> p.Phe459Leufs*79', 'DNAMutation --> p.Gly159Argfs*68', 'Disease --> osteopetrosis', 'Disease --> bicitopenia', 'Gene --> osteoclastos', '']
# ['Gene --> MEFV', 'Disease --> Púrpura de Schönlein-Henoch', 'OtherMutation --> M694V', 'OtherMutation --> M680I', 'OtherMutation --> A744S', 'OtherMutation --> R202Q', 'OtherMutation --> K695R', 'OtherMutation --> E148Q']
# ['DNAMutation --> CLCN5']
# ['Gene --> RUNX2', 'Disease --> displasia cleidocraneal', 'DNAMutation --> mutaciones', 'Gene --> RUNX2', 'Disease --> displasias esqueléticas', 'Gene --> RUNX2', 'OtherMutation --> macrocefalia real']
# ['Gene --> SPINK5', 'Disease --> Síndrome de Netherton', 'OtherMutation --> mutación recesiva', 'Disease --> insuficiencia respiratoria', 'Disease --> hipotermia', 'Disease --> eritrodermia']
# ['Gene --> BRCA', 'Disease --> cáncer de mama', 'OtherMutation --> mutaciones en genes BRCA', 'DNAMutation --> mutaciones en genes BRCA', 'Transcript --> mastectomía profiláctica ', 'Disease --> efectos adversos frecuentes', 'Disease --> incidencia de cáncer de mama', 'Disease --> mortalidad']
# ['Tipo de entidad no encontrada.']
# ['Gene --> gen de la glicerol kinasa', 'Disease --> hipertrigliceridemia', 'DNAMutation --> deleción en el gen de la glicerol kinasa', 'Gene --> gen de la glicerol kinasa']
# ['Gene --> EXT1', 'DNAMutation --> c.1219CT, (p.Gln407Stop)']
# ['Disease --> leucodistrofia hipomielinizante de tipo 6', 'Gene --> TUBB4A', 'DNAMutation --> mutaciones en heterocigosis', 'Disease --> retraso de la marcha', 'OtherMutation --> variante patogena', 'Disease --> afectacion cognitiva', 'OtherMutation --> condicionada por ', 'Disease --> deterioro progresivo', 'Disease --> dependencia total', 'Disease --> fallecimiento']
# ['DNAMutation --> SNP C/T-13910']
# ['Gene --> CaSR', 'Disease --> hipercalcemia hipocalciúrica familiar', 'OtherMutation --> mutación en exón 6 (c.1651A>G) del gen CaSR', 'DNAMutation --> c.1651A>G', '']
# ['Disease --> Síndrome de Sjögren-Larsson', 'Gene --> ALDH3A2', 'OtherMutation --> mutación', 'Gene --> ALDH3A2', 'DNAMutation --> mutación', 'Gene --> ALDH3A2', 'Gene --> ALDH3A2', 'OtherMutation --> deficiencia enzimática', 'OtherMutation --> acumulación', 'DNAAllele --> alcoholes', 'DNAAllele --> aldehídos grasos', 'Transcript --> tejidos', 'OtherMutation --> comprometen', 'Transcript --> membrana celular', 'Disease --> síndrome de Sjogren-Larsson', 'Disease --> síndrome de Sjogren-Larsson', 'OtherMutation --> diagnóstico', 'Transcript --> actividad de la enzima', 'Disease --> síndrome de Sjogren-Larsson', 'OtherMutation --> estudio', 'Disease --> síndrome de Sjogren-Larsson', 'Disease --> síndrome de Sjogren-Larsson']
# ['Gene --> BRCA1', 'Disease --> cáncer de mama', 'Disease --> cáncer de ovario', 'OtherMutation --> mutación del gen BRCA1', 'Transcript --> cirugía reductora de riesgo en trompas y ovarios', 'Transcript --> mastectomía bilateral']
# ['DNAMutation --> c.142G>T', 'DNAAllele --> p.Glu48X', 'Gene --> PCDH19', 'Disease --> Síndrome epiléptico ligado al cromosoma X por mutación de la protocaderina 19', 'Disease --> epilepsia con retardo mental ligado al cromosoma X por mutación del gen PCDH19', 'OtherMutation --> mutación del PCDH19']
# ['Disease --> Cáncer Medular de Tiroides', 'Gene --> RET', 'Disease --> Carcinoma Medular de Tiroides Familiar', 'Disease --> Neoplasia Endocrina Múltiple tipo 2']
# ['Gene --> MC4R', 'Gene --> FTO', 'Gene --> ADRB1', 'DNAMutation --> PON1-192', 'Gene --> ADIPOR2 (rs11061971)', 'SNP --> AMY', 'NucleotideChange-BaseChange --> AMY', 'OtherMutation --> microbiota intestinal', 'Disease --> obesidad y sobrepeso']
# ['Gene --> IL6R', 'Gene --> TLR3', 'Gene --> DC-SIGN', 'DNAMutation --> rs8192284', 'DNAMutation --> rs3775290', 'DNAMutation --> rs7248637', 'DNAAllele --> C', 'DNAAllele --> A', 'DNAAllele --> A', 'SNP --> rs8192284', 'SNP --> rs3775290', 'SNP --> rs7248637', 'NucleotideChange-BaseChange --> C/C', 'NucleotideChange-BaseChange --> A/A', 'OtherMutation --> CAG']
# ['Gene --> FMR1', 'DNAMutation --> CGG (citosina, guanina, guanina)', 'Disease --> síndrome de fragilidad del cromosoma X', 'Disease --> discapacidad intelectual heredable', 'Disease --> trastornos del espectro autista', 'Disease --> insuficiencia ovárica primaria', 'Disease --> síndrome de temblor/ataxia asociado a X frágil', 'OtherMutation --> hipermetilación ', 'OtherMutation --> reducción de niveles de expresión de FMRP', 'SNP --> Xq27.3', 'Transcript --> FMRP']
# ['Disease --> Síndrome de Ehlers-Danlos ', 'Gene --> PLOD1 ', 'OtherMutation --> mutaciones en el gen PLOD1 ', 'Gene --> FKBP14 ', 'DNAMutation --> FKBP14 c.362dupC ', 'OtherMutation --> variante recesiva que compromete el gen FKBP14']
# ['Disease --> acidemia propiónica', 'Gene --> PCCA', 'DNAMutation --> c.893A>G', 'OtherMutation --> p.K298R', 'DNAMutation --> c.937C>T', 'OtherMutation --> p.R313X']
# ['DNAMutation --> rapsina', 'DNAMutation --> rapsina ', 'Gene --> rapsina', 'Disease --> Síndrome miasténico congénito', 'Disease --> neumonía e insuficiencia ventilatoria']
# ['Gene --> ARNr ', 'Gene --> Helicobacter pylori', '', 'Disease --> dispepsia', '', 'DNAMutation --> A2142G', 'DNAMutation --> A2143G', '', 'SNP --> None', '', 'DNAAllele --> None', '', 'NucleotideChange-BaseChange --> None', '', 'OtherMutation --> None', '', 'Transcript --> None']
# ['Gene --> BRAF', 'DNAMutation --> mutación', 'Disease --> melanoma maligno', 'NucleotideChange-BaseChange --> exón 15', 'OtherMutation --> mutaciones', '']
# ['Disease --> leishmaniasis mucosa', 'Gene --> Leishmania (Viannia) brasiliensis', 'OtherMutation --> Montenegro', 'Gene --> L. (V) panamensis', 'Gene --> L. (V.) guyanensis', 'Gene --> L. (L.) amazonensis']
# ['Gene -->  ARNr  ', 'DNAMutation -->  A2143G  ', 'DNAMutation -->  A2142G  ', 'Disease --> Helicobacter pylori  ', '']
# ['Disease --> retinopatia', 'Disease --> hemiparesia derecha', 'Gene --> CTC1', 'DNAMutation --> mutaciones']
# ['Disease --> RASopatías', 'Gene --> PTPN11', 'DNAMutation --> c.922A>G', 'DNAAllele --> p.Asn308Asp', 'Gene --> RAF1', 'DNAMutation --> c.1467G>C', 'DNAAllele --> p.Leu489Phe', 'Disease --> síndrome cardiofaciocutáneo', 'Gene --> BRAF', 'Disease --> síndrome de Costello', 'Gene --> HRAS', 'Disease --> síndrome de Noonan', 'Gene --> SOS1', 'Disease --> síndrome de Noonan', 'DNAMutation --> c.922A>G', 'DNAAllele --> p.Asn308Asp', 'Disease --> síndrome de Noonan con múltiples lentigos', 'Gene --> PTPN11', 'DNAAllele --> el 100 %']
# ['Gene --> WT1', 'Gene --> PAX6', 'Disease --> Síndrome WAGR', 'Disease --> tumor de Wilms', 'OtherMutation --> deleción', 'NucleotideChange-BaseChange --> región 11p13', 'Transcript --> haploinsuficiencia']
# ['DNAAllele --> CYP2C9*2', 'DNAAllele --> CYP2C9*3', 'DNAMutation --> rs1799853', 'DNAMutation --> rs1057910']
# ['Gene --> APOA1', 'SNP --> rs670', 'OtherMutation --> alelo A']
# ['DNAMutation --> mutación de la isocitrato deshidrogenasa (IDH)', 'Gene --> 1p19q', 'Disease --> tumores cerebrales', 'OtherMutation --> cambios diagnósticos', 'Transcript --> gliomas cerebrales', 'Disease --> astrocitomas', 'Disease --> oligodendrogliomas', 'Disease --> grados II-IV', 'OtherMutation --> reclasificación diagnóstica', 'Disease --> grado IV', 'Transcript --> crisis', 'OtherMutation --> gliomas reclasificados', 'Disease --> edema', 'Disease --> lesiones únicas', 'Disease --> multiplicidad']
# ['Elementos irrelevantes fueron omitidos.', '', 'Elementos irrelevantes fueron omitidos.', '', 'Elementos irrelevantes fueron omitidos.', '', 'Cu --> cobre', 'Cu --> Cu', 'Cu --> Cu', 'OtherMutation --> bariátrica']
# ['Gene --> MBD5 ', 'DNAMutation --> c.397+1G>C', 'Disease --> retraso mental autosómico dominante 1, pseudo-Angelman, trastorno del neurodesarrollo asociado a MBD5, haploinsuficiencia MBD5', 'OtherMutation --> microdeleción del cromosoma 2q23.1', 'Disease --> heterotopía en banda bilateral', 'Disease --> polimicrogiria', 'Transcript --> exoma']
# ['Gene --> CFTR', 'DNAMutation --> ΔF508', 'OtherMutation --> 7T/9T', 'SNP --> 5T', 'Disease --> Fibrosis quística', 'Transcript --> ICSI']
# ['Transportadores ABC --> ABC', 'resistencia a fármacos --> resistencia a fármacos', 'epilepsia --> epilepsia', 'cambios --> cambios', 'actividad --> actividad', 'transportadores ABC --> ABC', 'resistencia --> resistencia', 'fármacos antiepilépticos --> fármacos antiepilépticos', 'tratamientos farmacológicos --> tratamientos farmacológicos', 'revisión bibliográfica --> revisión bibliográfica', 'transportadores ABC --> ABC', 'barrera hematoencefálica --> barrera hematoencefálica', 'resistencia --> resistencia', 'fármacos antiepilépticos --> fármacos antiepilépticos', 'estudios en humanos --> estudios en humanos', 'modelos animales --> modelos animales', 'variantes genéticas --> variantes genéticas', 'genes --> genes', 'ABCB1 --> ABCB1', 'ABCC2 --> ABCC2', 'transportadores --> transportadores', 'estudios genómicos --> estudios genómicos', 'epilepsia --> epilepsia', 'patologías afines --> patologías afines', 'alcances --> alcances', 'limitaciones --> limitaciones', 'asociación --> asociación', 'variantes genéticas --> variantes genéticas', 'transportadores ABC --> ABC', 'resistencia --> resistencia', 'fármacos anticonvulsivantes --> fármacos anticonvulsivantes', 'debate --> debate', 'tecnologías de secuenciación modernas --> tecnologías de secuenciación modernas', 'marcadores genéticos --> marcadores genéticos', 'medicina de precisión --> medicina de precisión', 'tratamiento --> tratamiento', 'epilepsia --> epilepsia']
# ['Gene --> ZFY ', 'OtherMutation --> 46 XX testicular no sindrómico']
# ['DNAMutation --> SMN1', 'Gene --> SMN1', 'Disease --> atrofia muscular espinal', 'Gene --> SMN2', 'DNAMutation --> SMN2', 'OtherMutation --> mutado', 'DNAAllele --> SMN1', 'DNAAllele --> SMN2', 'Transcript --> mRNA', 'OtherMutation --> afecta']
# ['Gene --> BTK', 'DNAMutation --> mutaciones', 'Gene --> IGHM', 'OtherMutation --> mutaciones hereditarias', 'OtherMutation --> mutaciones de novo.']
# ['Gene --> RETN', 'SNP --> rs10401670', 'DNAMutation --> T/C', 'Disease --> diabetes mellitus de tipo 2', 'OtherMutation --> alelo mutado T', 'DNAAllele --> alelo T', 'NucleotideChange-BaseChange --> C/T', 'Transcript --> 3´UTR']
# ['Gene --> BRCA1', 'DNAMutation --> 3450del4', 'Disease --> Cáncer de mama', 'Disease --> Cáncer de ovario', 'Disease --> Cáncer de próstata']
# ['Disease --> adenomas hipofisarios aislados', 'OtherMutation --> neoplasia endocrina múltiple de tipo 1 (NEM1)', 'OtherMutation --> complejo de Carney (CNC)', 'Disease --> FIPA', 'Disease --> FIPA homogéneo', 'Gene --> aryl hydrocarbon receptor interacting protein (AIP)']
# ['DNAMutation --> PCR', 'Gene --> EBV', 'Gene --> EBNA3C', 'Gene --> LMP1', 'SNP --> EBV-1', 'OtherMutation --> Raji', 'Disease --> linfoma de Burkitt']
# ['Disease --> síndrome de Pierson ', 'Gene --> LAMB2 ', 'DNAMutation --> c.1890G>C ', 'DNAAllele --> p.Q630H ', 'OtherMutation --> mutación homocigota novedosa ', 'Disease --> síndrome de Pierson ', 'Gene --> LAMB2']
# ['Disease --> osteoporosis', 'Disease --> osteoporosis primaria', 'Disease --> osteoporosis-pseudoglioma', 'Gene --> LRP5', 'DNAMutation --> nueva variante inactivante', 'Transcript --> Wnt/β-catenina']
# ['DNAMutation --> JAK2V617F', 'Disease --> micosis fungoides', 'Disease --> trombocitemia esencial', 'OtherMutation --> BCR/ABL']
# ['DNAMutation --> c.1126G>A p.A376T ', 'Gene --> ADCY5', 'Disease --> discinesia de la mutación ADCY5', 'Disease --> síndrome de Meige', 'Disease --> trastornos del movimiento', 'Disease --> discinesia familiar autosómica']
# ['Gene --> CFTR', 'Disease --> fibrosis quística', 'OtherMutation --> enfermedad genética de carácter autosómico recesivo', 'Transcript --> prueba diagnóstica de secuenciación del gen CFTR', 'SNP --> portadores asintomáticos familiares', 'OtherMutation --> concepciones', 'DNAAllele --> niño enfermo con fibrosis quística', 'OtherMutation --> prueba genética de detección de portadores del gen CFTR']
# ['DNAAllele --> rs16147', 'Gene --> gen del neuropéptido Y', 'Disease --> obesos', 'OtherMutation --> alelo menor', 'DNAMutation --> GG y GA + AA', 'NucleotideChange-BaseChange --> (-0,9 ± 1,1 UI/L vs. -4,4 ± 1,0 UI/L; p = 0,01),(0,7 ± 0,3 UI/L vs. -2,2 ± 0,9 UI/L: p = 0,02),(-0,3 ± 0,1 unidades vs. -1,2 ± 0,3 unidades; p = 0,02),(-0,3 ± 0,2 unidades vs. -0,7 ± 0,1 unidades: p = 0,01)', 'Transcript --> dieta M, dieta C']
# ['Gene --> tdh', 'Gene --> trh', '']
# ['Disease --> síndrome miasténico congénito de canal lento', 'Gene --> CHRNB1', 'DNAMutation --> c.865G>A', 'DNAAllele --> p.Val289Met', 'OtherMutation --> heterocigota', 'Transcript --> NM_000747.2']
# ['Gene --> gdh', 'Gene --> beta-giardin', 'Disease --> giardiasis', 'DNAMutation --> PCR-RFLP', 'DNAMutation --> secuenciación', 'DNAAllele --> conjunto A', 'DNAAllele --> conjunto B', 'DNAAllele --> subconjunto AII', 'DNAAllele --> AI', 'DNAAllele --> BIV', 'DNAAllele --> BIII']
# ['Disease --> leucoencefalopatía megalencefálica con quistes', 'Disease --> macrocefalia progresiva', 'Disease --> epilepsia', 'Gene --> MLC1']
# ['Disease --> Síndrome de Phelan-McDermid', 'Gene --> SHANK3', 'DNAMutation --> deleción del extremo terminal del cromosoma 22 región q13.3', 'SNP --> ', 'DNAAllele --> ', 'NucleotideChange-BaseChange --> ', 'OtherMutation --> mutaciones puntuales que afectan al gen SHANK3', 'Transcript -->']
# ['Gene --> RNASEH2B', 'Disease --> Síndrome de Aicardi-Goutières', 'Gene --> RNASEH2B', 'DNAAllele --> p.Ala177Thr', 'OtherMutation --> homocigosis', 'Disease --> síndrome de Aicardi-Goutières', 'Gene --> RNASEH2B', 'Disease --> síndrome de Aicardi-Goutières', 'DNAMutation --> tetraparesia espástica']
# ['Disease --> candidiasis mucocutánea crónica', 'Disease --> hipoparatiroidismo', 'Disease --> insuficiencia suprarrenal', 'Gene --> AIRE', 'DNAMutation --> variante patogénica']
# ['DNAMutation --> His1047Arg', 'DNAMutation --> Glu542Lys', 'DNAMutation --> Cys420Arg', 'OtherMutation --> mosaicismo', 'Disease --> hiperplasia muscular congénita', 'Gene --> PIK3CA']
# ['DNAMutation --> BRAFV600E', 'Disease --> gliomas', 'Gene --> BRAF', 'Drug --> vemurafenib', 'Drug --> dabrafenib', 'Disease --> quimioterapia', 'Disease --> radioterapia']
# ['Gene --> CLN6', 'Disease --> lipofuscinosis ceroidea neuronal, neurorregresión, epilepsias mioclónicas progresivas, variante infantil tardía de CLN6', 'DNAMutation --> c.552del, c.244G>C (p.Gly82Arg)', 'OtherMutation --> sustitución G>C (Gly82Arg)', 'Transcript -->  panel de lipofuscinosis']
# ['Gene --> KCNB1', 'Disease --> encefalopatía KCNB1', 'DNAMutation --> variantes', 'OtherMutation --> heterocigosis, mutación', 'Transcript --> Canal de potasio dependiente del voltaje', 'Disease --> encefalopatías epilépticas, síndrome de West, trastorno del espectro autista, trastorno por déficit de atención/hiperactividad, epilepsia refractaria', 'DNAMutation --> de novo', 'DNAMutation --> mosaicismo germinal', 'Disease --> discapacidad intelectual leve-moderada, trastorno del espectro autista, trastorno por déficit de atención/hiperactividad', 'DNAMutation --> mutación en KCNB1', 'Disease --> alteraciones en la resonancia magnética cerebral, atrofia cortical evolutiva', 'Disease --> crisis polimorfas (atónicas, hipermotoras, disautonómicas y tónicas), trastorno del movimiento caracterizado por ataxia, discinesias y temblor, crisis atónicas', 'DNAMutation --> heredaron la variante']
# ['Disease --> enfermedad de Erdheim-Chester', 'Gene --> gen BRAF', 'DNAMutation --> mutación en el gen BRAF', 'Disease --> hipofisitis autoinmunitaria', 'OtherMutation --> mutación', 'Transcript --> dabrafenib']
# ['Gene --> BRCA1', 'Gene --> BRCA2', 'DNAMutation --> InDels', 'DNAAllele --> polimorfismo de nucleótido simple', 'OtherMutation --> artefactos', 'Transcript --> Ion AmpliSeq BRCA1/BRCA2']
# ['Disease --> Enfermedad de Erdheim-Chester', 'Gene --> MAP2K1', 'DNAMutation --> mutación', 'OtherMutation --> clonal', 'Trascript --> MEK']
# ["''"]
# ['Disease --> hipofosfatasia', 'Gene --> ALPL', 'OtherMutation --> mutaciones heterocigotas compuestas', 'DNAMutation --> novedosa', 'Transcript --> gen ALPL']
# ['Gene --> RARS2', 'DNAMutation --> heterocigota', 'OtherMutation --> autosómica recesiva', 'Disease --> hipoplasia pontocerebelosa tipo 6', 'Gene --> RARS2', 'Disease --> hipoplasia pontocerebelosa tipo 6']
# ['Gene --> katG', 'DNAMutation --> S531L', 'Gene --> inhA', 'DNAMutation --> D516V', 'Disease --> resistencia a rifampicina', 'Disease --> resistencia a isoniacida', 'OtherMutation --> c-15t']
# ['Gene --> STAG3', 'Disease --> insuficiencia ovárica prematura', 'DNAMutation --> c.2773delT', 'ProteinMutation --> p.Ser925Profs*6']
# ['Gene --> SARS-CoV-2', 'DNAMutation --> alfa', 'DNAMutation --> gamma', 'DNAMutation --> delta', 'DNAMutation --> mu', 'DNAMutation --> ómicron', 'Gene --> Wuhan-Hu-1', 'DNAAllele --> proteína espiga']
# ['Gene --> FBN1', 'Disease --> síndrome de Marfan', 'DNAMutation --> c.3037G>A', 'DNAMutation --> p.Gly225Arg', 'OtherMutation --> cambio de sentido', 'OtherMutation --> truncadas', 'Transcript --> exón 23', 'Transcript --> exón 24']
# ['Gene --> APC', 'Gene --> KRAS', 'Gene --> TP53', 'Gene --> BRAF', 'Disease --> cáncer colorrectal', 'DNAMutation --> mutación', 'DNAMutation --> mutaciones', 'DNAMutation --> secuenciación de Sanger', 'DNAMutation --> inestabilidad cromosómica', 'DNAMutation --> inestabilidad microsatelital', 'DNAMutation --> epigenética', 'DNAMutation --> mutaciones en los genes APC, KRAS y TP53', 'DNAMutation --> mutación de los genes APC, KRAS y TP53', 'DNAMutation --> mutaciones detectadas', 'DNAMutation --> metilación del promotor del gen MLH1', 'DNAMutation --> metilación en el gen MLH1', 'DNAMutation --> metilación del gen MLH1', 'DNAMutation --> mutaciones en los genes APC, KRAS y TP53 fueron más frecuentes que en el grupo de tumores con inestabilidad microsatelital', 'DNAMutation --> las mutaciones detectadas se localizaron con mayor frecuencia en el colon derecho', 'SNP --> Short Tandem Repeat', 'OtherMutation --> inestabilidad microsatelital', 'OtherMutation --> tumores con metilación en el gen MHL1', 'OtherMutation --> tumores con estabilidad microsatelital', 'OtherMutation --> tumores con inestabilidad microsatelital presentaban metilación en el gen MLH1', 'Transcript --> MS-PCR']
# ['Disease --> enfermedad de Pompe', 'Disease --> miopatía metabólica', 'Disease --> LOPD', 'Gene --> gen GAA', 'DNAMutation --> c.-32-13T>G', 'DNAMutation --> c.1799G>A', 'DNAMutation --> c.1082C>T', 'OtherMutation --> variantes patogénicas', 'NucleotideChange-BaseChange --> c.-32-13T>G', 'NucleotideChange-BaseChange --> c.1799G>A', 'NucleotideChange-BaseChange --> c.1082C>T']
# ['Gene --> SMN1', 'Gene --> SMN2', 'Drug --> nusinersen', 'Drug --> onasemnogene abeparvovec-xioi (OAX)', 'Disease --> Atrofia muscular espinal (AME)', 'Transcript --> proteína de supervivencia de la motoneurona (SMN)']
# ['Gene --> KMT2B', 'Disease --> distonía generalizada de inicio temprano', 'Gene --> KMT2B', 'Disease --> enfermedad neurológica', 'Disease --> distonía focal', 'Disease --> distonía generalizada', 'Disease --> compromiso cervical', 'Disease --> trastorno secundario de la deglución', 'Disease --> discapacidad intelectual', 'SNP --> c.1205delC', 'DNAMutation --> p.(Pro402Hisfs*5)', 'DNAAllele --> heterocigota', 'NucleotideChange-BaseChange --> c.1205delC, p.(Pro402Hisfs*5)', 'OtherMutation --> desplazamiento en el marco de lectura. ', 'Disease --> distonía de inicio temprano autosómica dominante']
# ['Gene --> CLOCK', 'SNP --> rs3749474T/C', 'NucleotideChange-BaseChange --> T/C', 'SNP --> rs3749474', 'OtherMutation --> alelo T', 'Disease --> obesidad', 'OtherMutation --> CC', 'Transcript --> genotipos', 'SNP --> rs3749474', 'OtherMutation --> alelo T', 'OtherMutation --> no riesgo', 'OtherMutation --> riesgo', 'Gene --> CLOCK', 'OtherMutation --> alelo T', 'Disease --> obesidad', 'Disease --> pérdida de peso', 'OtherMutation --> CC', 'OtherMutation --> no riesgo', 'OtherMutation --> riesgo', 'Transcript --> genotipos', 'SNP --> rs3749474', 'OtherMutation --> alelo T', 'SNP --> rs3749474', 'Gene --> CLOCK', 'OtherMutation --> T y C', 'OtherMutation --> CC', 'OtherMutation --> riesgo', 'OtherMutation --> no riesgo', 'OtherMutation --> riesgo', 'OtherMutation --> no riesgo', 'OtherMutation --> riesgo', 'OtherMutation --> no riesgo', 'SNP --> rs3749474', 'OtherMutation --> alelo T', 'Gene --> CLOCK', 'OtherMutation --> alelo T', 'SNP --> rs3749474', 'Disease --> obesidad', 'Transcript --> ciclos circadianos', 'Disease --> conducta alimentaria', 'Disease --> obesidad', 'OtherMutation --> ancestría genética', 'Transcript --> estudios de asociación', 'Disease --> ciclos circadianos', 'Disease --> obesidad', 'Transcript --> pruebas clínicas personalizadas']
# ['Gene --> BRCA1', 'Gene --> BRCA2', 'Disease --> Cáncer de Mama', 'Disease --> Cáncer de Ovario', 'DNAMutation --> mutaciones', 'Gene --> BRCA1', 'Gene --> BRCA2', 'Disease --> cáncer', 'Gene --> BRCA1', 'Gene --> BRCA2', 'Disease --> histología ductal', 'DNAAllele --> TN', 'Gene --> BRCA1', 'Gene --> BRCA2', 'Disease --> Cáncer de Mama', 'DNAAllele --> TN', 'Gene --> BRCA1', 'Gene --> BRCA2', 'Disease --> HBOC', 'DNAMutation --> mutaciones', 'DNAMutation --> mutaciones', 'DNAAllele --> VP', 'DNAAllele --> VP', 'DNAAllele --> VP']
# ['Disease --> neutropenia congénita grave (NCG)', 'Gene --> elastasa 2 (ELA 2)', 'Disease --> infecciones graves', 'Disease --> déficit de la enzima glucosa 6 fosfato deshidrogenasa, subunidad catalítica 3 (G6PC3)']
# ['DNAMutation --> DGAT1', 'Gene --> DGAT1', 'Disease --> diarreas y enteropatías congénitas (CODE por su sigla en inglés)', 'Disease --> diarrea crónica grave de aparición temprana', 'Disease --> retraso en el crecimiento', 'Disease --> vómitos', 'Disease --> hipoalbuminemia', 'DNAMutation --> DGAT1', 'OtherMutation --> compuesto heterocigota ', 'Gene --> DGAT1', 'DNAMutation --> DGAT1', 'OtherMutation --> esta mutación', 'Disease --> diarreas congénitas']
# ['Gene --> SLC2A1', 'Disease --> síndrome de deficiencia del transportador de glucosa tipo 1', 'Disease --> retraso en la adquisición de pautas madurativas', 'Disease --> epilepsia farmacorresistente', 'Disease --> desórdenes del movimiento', 'OtherMutation --> terapia cetogénica']
# ['Gene --> DMP1', 'Disease --> raquitismo hipofosfatémico autosómico recesivo', 'Disease --> raquitismo hipofosfatémico hereditario', 'Disease --> deformidad esquelética', 'Disease --> retraso del crecimiento', 'Disease --> raquitismo hipofosfatémico', 'Disease --> condición extremadamente poco frecuente', 'Disease --> mutaciones con pérdida de función del gen DMP1', 'DNAAllele --> pérdida de función', '']
# ['Gene --> telomerasa', 'DNAMutation --> C228T', 'DNAMutation --> C250T', 'Disease --> meningiomas', 'Disease --> meningiomas anaplásicos', 'OtherMutation --> mutaciones en la región promotora de la transcriptasa inversa de la telomerasa', 'Transcript --> gen de la transcriptasa inversa de la telomerasa']
# ['Gene --> SOD1', 'Gene --> C9orf72', 'Disease --> esclerosis lateral amiotrófica', 'DNAMutation --> G93A (en el gen SOD1)', 'DNAMutation --> D90A (en el gen SOD1)', 'OtherMutation --> alelo con una significativa prevalencia en los pacientes del estudio (en el locus C9orf72)', 'DNAAllele --> 8 repeticiones del hexanucleótido G4C2 (en el locus C9orf72)']
# ['DNAAllele --> Factor V Leiden']
# ['Gene --> POLG', 'Disease --> ataxia sensitiva', 'Disease --> neuropatía sensitiva', 'DNAMutation --> variantes patógenas', 'OtherMutation --> homocigotos o heterocigotos compuestos', 'NucleotideChange-BaseChange --> sin especificar', 'OtherMutation --> anomalías oculomotoras']
# ['Gene --> CLCN1', 'Disease --> Miotonía congénita', 'DNAMutation --> CLCN1: c.824T>C', 'OtherMutation --> Mutación probablemente patogénica', 'Gene --> CLCN1']
# ['Gene --> CLOCK', 'SNP --> rs1554483', 'SNP --> rs4864548', 'Disease --> obesidad', 'Disease --> sobrepeso']
# ['Disease --> enfermedad de moyamoya', 'Gene --> RNF213', 'DNAMutation --> c.12185G>A', 'DNAMutation --> p.(Arg4062Gln)', 'SNP --> p.R4810K']
# ['Disease --> fibrosis quística', 'Gene --> CFTR', 'OtherMutation --> proteína de canal mutada', 'Disease --> complicaciones hepáticas', 'OtherMutation --> obstrucción biliar secundaria a la presencia de secreciones espesas', 'Disease --> cirrosis', 'DNAMutation --> ácido ursodesoxicólico', 'Disease --> hipertensión portal', 'Gene --> CFTR', 'OtherMutation --> modulador de tolerancia inmune', 'Disease --> inflamación portal persistente', 'Disease --> fibrosis', 'OtherMutation --> eje intestino-hígado']
# ['Protein --> proteína CFTR', 'Disease --> fibrosis quística', 'Drug --> lumacaftor/ivacaftor', 'Disease --> fibrosis quística', 'OtherMutation --> defecto', 'Transcript --> CFTR', 'NucleotideChange-BaseChange --> ppVEF1', 'Gene --> IMC', 'NucleotideChange-BaseChange --> puntaje Z de IMC', 'OtherMutation --> días de uso de antibiótico', '']
# ['Gene --> 23S rRNA', 'DNAMutation --> A2059G', 'Gene --> parC', 'DNAMutation --> G295', 'DNAMutation --> G248T']
# ['Gene --> CACNA1A', 'Disease --> Ataxia episódica tipo 2', 'Disease --> epilepsia', 'Disease --> migraña', 'Disease --> distonía', 'Disease --> encefalopatía epiléptica de inicio precoz de tipo 42', 'DNAMutation --> mutación en CACNA1A', 'DNAAllele --> heterocigotos', 'DNAAllele --> homocigota', 'SNP --> variantes diferentes de CACNA1A', 'OtherMutation --> factores desencadenantes', 'OtherMutation --> estrés', 'NucleotideChange-BaseChange --> 4-aminopiridina', 'Transcript --> acetazolamida', 'Disease --> nefrolitiasis', 'Disease --> atrofia cerebelosa']
# ['Disease --> Enfermedad granulomatosa crónica', 'Gene --> CYBB', 'Gene --> EROS', 'Gene --> NCF1', 'Gene --> NCF2', 'Gene --> NCF4', 'Gene --> CYBA', 'Gene --> NCF2', 'DNAMutation --> c.304 C>T', 'OtherMutation --> p.Arg102*', 'DNAMutation --> c.1369 A>T', 'OtherMutation --> p.Lys457*', 'DNAMutation --> c.979 G>T', 'OtherMutation --> p.Gly327*']
# ['Gene --> WAS', 'DNAMutation --> c.295C>T', 'Disease --> Síndrome de Wiskott-Aldrich', 'OtherMutation --> trombocitopenia autoinmune', 'Disease --> otitis media aguda', 'OtherMutation --> sepsis por Haemophilus influenzae', 'OtherMutation --> infección por Streptococcus pneumoniae', 'OtherMutation --> exacerbación de eccema', 'OtherMutation --> S. epidermidis', 'OtherMutation --> fiebre de origen indeterminado', 'Disease --> fenotipo leve del síndrome de Wiskott-Aldrich', 'OtherMutation --> herencia ligada al cromosoma X']
# ['Gene --> miotubularina (MTM1)', 'Disease --> miopatía miotubular ', 'Disease --> miopatía miotubular ligada al cromosoma X (XLMTM) ', 'OtherMutation --> mutación en el gen de la miotubularina (MTM1)', 'Disease --> miopatías congénitas ', 'Disease --> miopatía nemalínica', 'Disease --> miopatía con cores ', 'Disease --> bradicardia sinusal grave ', 'Disease --> bloqueo auriculoventricular ', 'SNP --> Holter', 'Disease --> bradicardia grave ', 'Disease --> afectación cardíaca primaria']
# ['DNAMutation --> mutaciones en mosaico en la vía de señalización AKT/PI3K/mTOR y RAS-MAPK', 'Disease --> síndromes de sobrecrecimiento corporal segmentario', 'Gene --> PIK3CA', 'Disease --> PROS', 'OtherMutation --> malformación vascular', 'OtherMutation --> capilar', 'Disease --> asimetría de longitud de miembros inferiores', 'OtherMutation --> necesidades básicas insatisfechas (NBI)']
# ['DNAMutation --> BRAF (codón 600)', 'DNAMutation --> NRAS (codón 61)', 'Disease --> carcinoma papilar de tiroides (CPT)', 'DNAMutation --> BRAF (Bethesda VI)', 'DNAMutation --> NRAS (lesión folicular)', 'Disease --> carcinoma folicular', 'SNP --> adenomas', 'OtherMutation --> variación (NRAS)', 'OtherMutation --> subtipos', 'OtherMutation --> lesión folicular', 'OtherMutation --> metástasis', 'OtherMutation --> riesgo relativo de recurrencia', 'OtherMutation --> Consenso Argentino Intersocietario']
# ['Gene --> KIF1A', 'Disease --> encefalopatía KIF1A-associated-neurological-disorder (KAND)', 'DNAMutation --> mutación de novo missense', 'OtherMutation --> alteración conductual', 'OtherMutation --> incontinencia urinaria', 'OtherMutation --> polineuropatía sensitivomotora', 'OtherMutation --> discapacidad intelectual', 'OtherMutation --> hipotonía axial', 'OtherMutation --> paraparesia espástica', 'NucleotideChange-BaseChange --> no se encontró ninguna', 'SNP --> no se encontró ninguna', 'DNAAllele --> no se encontró ninguna', 'Transcript --> proteína de la familia de las cinesinas 3']
# ['Gene --> RYR1', 'Disease --> miopatías relacionadas con el receptor de rianodina de tipo 1 (RYR1-RM), síntomas miopáticos, debilidad, retraso del desarrollo motor, miopatía central core, multiminicore, desproporción congénita de fibras', 'DNAMutation --> variantes del gen RYR1, variantes potencialmente patógenas del gen RYR1, variantes missense dominantes, cinco variantes genéticas no descritas con anterioridad', 'OtherMutation --> patrón de herencia', 'Transcript --> biopsia muscular']
